# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
RAW = "/content/drive/MyDrive/mental health survey report/"
coverage = pd.read_csv(RAW + "survey.csv")
